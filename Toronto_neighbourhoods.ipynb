# %% [markdown]
# # Import of all necessary libraries

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %% [markdown]
# # Making request to URL and making BeautifulSoup object for scraping

# %%
URL = 'http://en.turkcewiki.org/wiki/List_of_postal_codes_of_Canada:_M'
page = requests.get(URL)

soup = BeautifulSoup(page.content, 'lxml')

# %% [markdown]
# # Table tag of data

# %%
tble = soup.find('table')
print(len(tble))
# Out:
# 2

# %% [markdown]
# # Initialize empty lists for all the data

# %%
postal_codes=[]
boroughs = []
neighs = []

# %% [markdown]
# # Loop through all the cells of table and retrieve all the important information

# %%
for neigh in tble.find_all('td'):
  sp = neigh.find('span')
  if(sp.text != 'Not assigned'):
    postal_codes.append(neigh.find('b').text)
    data = sp.text
    split_both = data.split("(")
    hoods = split_both[1].split(")")[0]
    hoods_data = hoods.replace("/",",")
    boroughs.append(split_both[0])
    neighs.append(hoods_data)

# %% [markdown]
# # Checking for lengths of lists and discrepancies

# %%
print(len(postal_codes))
print(len(boroughs))
print(len(neighs))
# Out:
# 103
# 103
# 103

# %% [markdown]
# # Empty dataframe

# %%
df = pd.DataFrame(columns=['PostalCode','Borough','Neighbourhood'])
df
# Out:
# Empty DataFrame
# Columns: [PostalCode, Borough, Neighbourhood]
# Index: []

# %% [markdown]
# # Assigning data to columns

# %%
df['PostalCode'] =postal_codes
df['Borough'] = boroughs
df['Neighbourhood'] = neighs

df
# Out:
#     PostalCode  ...                                      Neighbourhood
# 0          M3A  ...                                          Parkwoods
# 1          M4A  ...                                   Victoria Village
# 2          M5A  ...                         Regent Park , Harbourfront
# 3          M6A  ...                  Lawrence Manor , Lawrence Heights
# 4          M7A  ...                      Ontario Provincial Government
# ..         ...  ...                                                ...
# 98         M8X  ...    The Kingsway , Montgomery Road , Old Mill North
# 99         M4Y  ...                               Church and Wellesley
# 100        M7Y  ...                                     Enclave of M4L
# 101        M8Y  ...  Old Mill South , King's Mill Park , Sunnylea ,...
# 102        M8Z  ...  Mimico NW , The Queensway West , South of Bloo...
#
# [103 rows x 3 columns]

# %% [markdown]
# # Checking unique postal codes in order to merge same postal code boroughs

# %%
len(df['PostalCode'].unique())
# Out:
# 103

# %% [markdown]
# # Getting data from CSV of geospatial data

# %%
from io import StringIO 
url = 'http://cocl.us/Geospatial_data'
s=requests.get(url).content
c=pd.read_csv(StringIO(s.decode('utf-8')))
c
# Out:
#     Postal Code   Latitude  Longitude
# 0           M1B  43.806686 -79.194353
# 1           M1C  43.784535 -79.160497
# 2           M1E  43.763573 -79.188711
# 3           M1G  43.770992 -79.216917
# 4           M1H  43.773136 -79.239476
# ..          ...        ...        ...
# 98          M9N  43.706876 -79.518188
# 99          M9P  43.696319 -79.532242
# 100         M9R  43.688905 -79.554724
# 101         M9V  43.739416 -79.588437
# 102         M9W  43.706748 -79.594054
#
# [103 rows x 3 columns]

# %% [markdown]
# # Merge Both the tables

# %%
df2= df.merge(c, left_on='PostalCode',right_on = 'Postal Code', how='left')
df2.drop(columns=['Postal Code'],inplace=True)
df2
# Out:
#     PostalCode  ...  Longitude
# 0          M3A  ... -79.329656
# 1          M4A  ... -79.315572
# 2          M5A  ... -79.360636
# 3          M6A  ... -79.464763
# 4          M7A  ... -79.389494
# ..         ...  ...        ...
# 98         M8X  ... -79.506944
# 99         M4Y  ... -79.383160
# 100        M7Y  ... -79.321558
# 101        M8Y  ... -79.498509
# 102        M8Z  ... -79.520999
#
# [103 rows x 5 columns]

# %% [markdown]
# # Exmine North York Borough of Toronto

# %%
df3 = df2[df2['Borough']=='North York']
df3
# Out:
#    PostalCode     Borough  ...   Latitude  Longitude
# 0         M3A  North York  ...  43.753259 -79.329656
# 1         M4A  North York  ...  43.725882 -79.315572
# 3         M6A  North York  ...  43.718518 -79.464763
# 7         M3B  North York  ...  43.745906 -79.352188
# 10        M6B  North York  ...  43.709577 -79.445073
# 13        M3C  North York  ...  43.725900 -79.340923
# 27        M2H  North York  ...  43.803762 -79.363452
# 28        M3H  North York  ...  43.754328 -79.442259
# 33        M2J  North York  ...  43.778517 -79.346556
# 34        M3J  North York  ...  43.767980 -79.487262
# 39        M2K  North York  ...  43.786947 -79.385975
# 40        M3K  North York  ...  43.737473 -79.464763
# 45        M2L  North York  ...  43.757490 -79.374714
# 46        M3L  North York  ...  43.739015 -79.506944
# 49        M6L  North York  ...  43.713756 -79.490074
# 50        M9L  North York  ...  43.756303 -79.565963
# 52        M2M  North York  ...  43.789053 -79.408493
# 53        M3M  North York  ...  43.728496 -79.495697
# 55        M5M  North York  ...  43.733283 -79.419750
# 57        M9M  North York  ...  43.724766 -79.532242
# 59        M2N  North York  ...  43.770120 -79.408493
# 60        M3N  North York  ...  43.761631 -79.520999
# 66        M2P  North York  ...  43.752758 -79.400049
# 72        M2R  North York  ...  43.782736 -79.442259
#
# [24 rows x 5 columns]

# %% [markdown]
# # Imports

# %%
from geopy.geocoders import Nominatim 
import folium
import json
from pandas.io.json import json_normalize 
import matplotlib.cm as cm
import matplotlib.colors as colors

from sklearn.cluster import KMeans

# %% [markdown]
# # Getting longitude and lattitude of North York

# %%
address = 'North York, Ontario'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Manhattan are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Manhattan are 43.7543263, -79.44911696639593.

# %% [markdown]
# # Generate map of all neighbourhoods in North York

# %%
map_north_york = folium.Map(location=[latitude, longitude], zoom_start=11)

for lat, lng, label in zip(df3['Latitude'],df3['Longitude'], df3['Neighbourhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_north_york)  
    
map_north_york
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_2a42c12cc23945cfa68b3cd777f55dd7%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_2a42c12cc23945cfa68b3cd777f55dd7%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_2a42c12cc23945cfa68b3cd777f55dd7%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_2a42c12cc23945cfa68b3cd777f55dd7%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B43.7543263%2C%20-79.44911696639593%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_35c439ed4b8a4b529c56da2d4a949fbb%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20 ...

# %% [markdown]
# # Defining foursquare credentials

# %%
CLIENT_ID = 'RFI4U14MUXCU2TS4TCEPPFVL2MVA2DC4VFFZAAX2334YMWF3' 
CLIENT_SECRET = 'NCCPVLPHQ05YAFD1ATX1B0A1AZXPOZ4MICI3V5KRHTYCJP0Ot'
VERSION = '20180605' 
LIMIT = 100 

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: RFI4U14MUXCU2TS4TCEPPFVL2MVA2DC4VFFZAAX2334YMWF3
# CLIENT_SECRET:NCCPVLPHQ05YAFD1ATX1B0A1AZXPOZ4MICI3V5KRHTYCJP0Ot

# %% [markdown]
# # Getting longitude and lattitude of the first neighbourhood

# %%
neighborhood_latitude = df3.loc[0, 'Latitude']
neighborhood_longitude = df3.loc[0, 'Longitude']

neighborhood_name = df3.loc[0, 'Neighbourhood'] 

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Latitude and longitude values of Parkwoods are 43.7532586, -79.3296565.

# %% [markdown]
# # Making a get request to foursquare API to explore venues near Parkwood

# %%
LIMIT =100
radius =500
AUTH = 'IKEMNNFA2KMSR1AEWHKN2HUZEV3HCQB3GNZHGQKJ4EZ3XL3O'
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&oauth_token={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    AUTH,
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '6098ec506d61f1572aca66b7'},
#  'notifications': [{'item': {'unreadCount': 0}, 'type': 'notificationTray'}],
#  'response': {'groups': [{'items': [{'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e8d9dcdd5fbbbb6b3003c7b-0',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'primary': True,
#          'shortName': 'Park'}],
#        'id': '4e8d9dcdd5fbbbb6b3003c7b',
#        'location': {'address': 'Toronto',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'distance': 245,
#         'formattedAddress': ['Toronto', 'Toronto ON', 'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.751976046055574,
#           'lng': -79.33214044722958}],
#         'lat': 43.751976046055574,
#         'lng': -79.33214044722958,
#         'state': 'ON'},
#        'name': 'Brookbanks Park',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '600917367'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-58d5b8d0102f4722b70e487b-1',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/realestate_',
#           'suffix': '.png'},
#          'id': '5454144b498ec1f095bff2f2',
#          'name': 'Construction & Landscaping',
#          'pluralName': 'Construction & Landscaping',
#          'primary': True,
#          'shortName': 'Construction'}],
#        'id': '58d5b8d0102f4722b70e487b',
#        'location': {'address': '21 Valley Woods Rd',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'distance': 198,
#         'formattedAddress': ['21 Valley Woods Rd',
#          'Toronto ON M3A 0A1',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.752622,
#           'lng': -79.331957}],
#         'lat': 43.752622,
#         'lng': -79.331957,
#         'postalCode': 'M3A 0A1',
#         'state': 'ON'},
#        'name': 'Careful & Reliable Painting',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-51d769f2498e3efc78bee6b9-2',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#           'suffix': '.png'},
#          'id': '4d954b0ea243a5684a65b473',
#          'name': 'Convenience Store',
#          'pluralName': 'Convenience Stores',
#          'primary': True,
#          'shortName': 'Convenience Store'}],
#        'id': '51d769f2498e3efc78bee6b9',
#        'location': {'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'distance': 230,
#         'formattedAddress': ['Toronto ON', 'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.754513133391214,
#           'lng': -79.33194239759004}],
#         'lat': 43.754513133391214,
#         'lng': -79.33194239759004,
#         'state': 'ON'},
#        'name': '649 Variety',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5fc825cac5b8dd60907c56b3-3',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'primary': True,
#          'shortName': 'Hotel'}],
#        'id': '5fc825cac5b8dd60907c56b3',
#        'location': {'address': '35 Valley Woods Road',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'distance': 286,
#         'formattedAddress': ['35 Valley Woods Road',
#          'Toronto ON M3A 2R5',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.7547545,
#           'lng': -79.3325523}],
#         'lat': 43.7547545,
#         'lng': -79.3325523,
#         'postalCode': 'M3A 2R5',
#         'state': 'ON'},
#        'name': 'Towns On The Ravine',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '1359110116'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-58f01a208f2c1a558cea5f7d-4',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/realestate_',
#           'suffix': '.png'},
#          'id': '5454144b498ec1f095bff2f2',
#          'name': 'Construction & Landscaping',
#          'pluralName': 'Construction & Landscaping',
#          'primary': True,
#          'shortName': 'Construction'}],
#        'id': '58f01a208f2c1a558cea5f7d',
#        'location': {'address': '1211-44 Valley Woods Rd',
#         'cc': 'CA',
#         'city': 'North York',
#         'country': 'Canada',
#         'distance': 301,
#         'formattedAddress': ['1211-44 Valley Woods Rd',
#          'North York ON M3A 2R7',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.75476,
#           'lng': -79.332783}],
#         'lat': 43.75476,
#         'lng': -79.332783,
#         'postalCode': 'M3A 2R7',
#         'state': 'ON'},
#        'name': 'Sun Life',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-53e72d92498e336f61db5bf5-5',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#           'suffix': '.png'},
#          'id': '52f2ab2ebcbc57f1066b8b3a',
#          'name': 'Fireworks Store',
#          'pluralName': 'Fireworks Stores',
#          'primary': True,
#          'shortName': 'Fireworks Store'}],
#        'id': '53e72d92498e336f61db5bf5',
#        'location': {'address': '18 Valley Woods Road #414',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'distance': 307,
#         'formattedAddress': ['18 Valley Woods Road #414',
#          'Toronto ON M3A 0A1',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.753396155415686,
#           'lng': -79.33347702026367}],
#         'lat': 43.753396155415686,
#         'lng': -79.33347702026367,
#         'postalCode': 'M3A 0A1',
#         'state': 'ON'},
#        'name': 'GTA Restoration',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4cb11e2075ebb60cd1c4caad-6',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/foodanddrink_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1f9941735',
#          'name': 'Food & Drink Shop',
#          'pluralName': 'Food & Drink Shops',
#          'primary': True,
#          'shortName': 'Food & Drink'}],
#        'id': '4cb11e2075ebb60cd1c4caad',
#        'location': {'address': '29 Valley Woods Road',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'distance': 312,
#         'formattedAddress': ['29 Valley Woods Road', 'Toronto ON', 'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.75197441585782,
#           'lng': -79.33311418516017}],
#         'lat': 43.75197441585782,
#         'lng': -79.33311418516017,
#         'state': 'ON'},
#        'name': 'Variety Store',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-53622a89498ed84d6853265e-7',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#           'suffix': '.png'},
#          'id': '52f2ab2ebcbc57f1066b8b4f',
#          'name': 'Bus Stop',
#          'pluralName': 'Bus Stops',
#          'primary': True,
#          'shortName': 'Bus Stop'}],
#        'id': '53622a89498ed84d6853265e',
#        'location': {'address': '44 Valley Woods Rd',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'distance': 405,
#         'formattedAddress': ['44 Valley Woods Rd', 'Toronto ON', 'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.75540238129278,
#           'lng': -79.33374133300899}],
#         'lat': 43.75540238129278,
#         'lng': -79.33374133300899,
#         'state': 'ON'},
#        'name': 'TTC stop - 44 Valley Woods',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-52b14b5311d21c7413910d73-8',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1df931735',
#          'name': 'BBQ Joint',
#          'pluralName': 'BBQ Joints',
#          'primary': True,
#          'shortName': 'BBQ'}],
#        'id': '52b14b5311d21c7413910d73',
#        'location': {'address': '76 Parkwoods Village dr.',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'distance': 406,
#         'formattedAddress': ['76 Parkwoods Village dr.',
#          'Toronto ON M3A 2X8',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.756650934496314,
#           'lng': -79.33152437210083}],
#         'lat': 43.756650934496314,
#         'lng': -79.33152437210083,
#         'postalCode': 'M3A 2X8',
#         'state': 'ON'},
#        'name': 'Bella Vita Catering & Private Chef Service',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5921cc82e96d0c63d980640c-9',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/realestate_',
#           'suffix': '.png'},
#          'id': '5454144b498ec1f095bff2f2',
#          'name': 'Construction & Landscaping',
#          'pluralName': 'Construction & Landscaping',
#          'primary': True,
#          'shortName': 'Construction'}],
#        'id': '5921cc82e96d0c63d980640c',
#        'location': {'address': '9-280 Hillmount Rd.',
#         'cc': 'CA',
#         'city': 'Markham',
#         'country': 'Canada',
#         'distance': 412,
#         'formattedAddress': ['9-280 Hillmount Rd.',
#          'Markham ON L6C 3A1',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.75243208667859,
#           'lng': -79.33466148402658}],
#         'lat': 43.75243208667859,
#         'lng': -79.33466148402658,
#         'postalCode': 'L6C 3A1',
#         'state': 'ON'},
#        'name': 'Corrosion Service Company Limited',
#        'photos': {'count': 0, 'groups': []}}}],
#     'name': 'recommended',
#     'type': 'Recommended Places'}],
#   'headerFullLocation': 'Parkwoods - Donalda, Toronto',
#   'headerLocation': 'Parkwoods - Donalda',
#   'headerLocationGranularity': 'neighborhood',
#   'suggestedBounds': {'ne': {'lat': 43.757758604500005,
#     'lng': -79.32343823984928},
#    'sw': {'lat': 43.7487585955, 'lng': -79.33587476015072}},
#   'totalResults': 10}}

# %% [markdown]
# # Retrieving categories of venues obtained

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [markdown]
# # Cleaning response and generating Dataframe

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) 

filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   This is separate from the ipykernel package so we can avoid doing imports until
#                           name  ...        lng
# 0              Brookbanks Park  ... -79.332140
# 1  Careful & Reliable Painting  ... -79.331957
# 2                  649 Variety  ... -79.331942
# 3          Towns On The Ravine  ... -79.332552
# 4                     Sun Life  ... -79.332783
#
# [5 rows x 4 columns]

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 10 venues were returned by Foursquare.

# %% [markdown]
# # Getting venues near all the neighbourhoods in north york borough

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    AUTH = 'IKEMNNFA2KMSR1AEWHKN2HUZEV3HCQB3GNZHGQKJ4EZ3XL3O'
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        url = 'https://api.foursquare.com/v2/venues/explore?&oauth_token={}&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            AUTH,
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# # Generating dataframe of all neighbourhoods

# %%
north_york_venues = getNearbyVenues(names=df3['Neighbourhood'],
                                   latitudes=df3['Latitude'],
                                   longitudes=df3['Longitude'])
north_york_venues
# Out:
# Parkwoods
# Victoria Village
# Lawrence Manor , Lawrence Heights
# Don Mills
# Glencairn
# Don Mills
# Hillcrest Village
# Bathurst Manor , Wilson Heights , Downsview North
# Fairview , Henry Farm , Oriole
# Northwood Park , York University
# Bayview Village
# Downsview
# York Mills , Silver Hills
# Downsview
# North Park , Maple Leaf Park , Upwood Park
# Humber Summit
# Willowdale , Newtonbrook
# Downsview
# Bedford Park , Lawrence Manor East
# Humberlea , Emery
# Willowdale
# Downsview
# York Mills West
# Willowdale
#     Neighborhood  ...              Venue Category
# 0      Parkwoods  ...                        Park
# 1      Parkwoods  ...  Construction & Landscaping
# 2      Parkwoods  ...           Convenience Store
# 3      Parkwoods  ...                       Hotel
# 4      Parkwoods  ...  Construction & Landscaping
# ..           ...  ...                         ...
# 423   Willowdale  ...                         Spa
# 424   Willowdale  ...                         Spa
# 425   Willowdale  ...               Grocery Store
# 426   Willowdale  ...                 Supermarket
# 427   Willowdale  ...                     Butcher
#
# [428 rows x 7 columns]

# %%
north_york_venues.head()
# Out:
#   Neighborhood  ...              Venue Category
# 0    Parkwoods  ...                        Park
# 1    Parkwoods  ...  Construction & Landscaping
# 2    Parkwoods  ...           Convenience Store
# 3    Parkwoods  ...                       Hotel
# 4    Parkwoods  ...  Construction & Landscaping
#
# [5 rows x 7 columns]

# %% [markdown]
# # Getting count of venues near neighbourhoods

# %%
north_york_venues.groupby('Neighborhood').count()
# Out:
#                                                    Neighborhood Latitude  ...  Venue Category
# Neighborhood                                                              ...
# Bathurst Manor , Wilson Heights , Downsview North                     34  ...              34
# Bayview Village                                                        6  ...               6
# Bedford Park , Lawrence Manor East                                    52  ...              52
# Don Mills                                                             41  ...              41
# Downsview                                                             24  ...              24
# Fairview , Henry Farm , Oriole                                       100  ...             100
# Glencairn                                                             12  ...              12
# Hillcrest Village                                                      6  ...               6
# Humber Summit                                                          3  ...               3
# Humberlea , Emery                                                      4  ...               4
# Lawrence Manor , Lawrence Heights                                     39  ...              39
# North Park , Maple Leaf Park , Upwood Park                             4  ...               4
# Northwood Park , York University                                      17  ...              17
# Parkwoods                                                             10  ...              10
# Victoria Village                                                       7  ...               7
# Willowdale                                                            58  ...              58
# Willowdale , Newtonbrook                                               3  ...               3
# York Mills , Silver Hills                                              3  ...               3
# York Mills West                                                        5  ...               5
#
# [19 rows x 6 columns]

# %% [markdown]
# # Unique categories of venues

# %%
print('There are {} uniques categories.'.format(len(north_york_venues['Venue Category'].unique())))
# Out:
# There are 135 uniques categories.

# %% [markdown]
# # One hot encoding categories for clustering

# %%
north_york_onehot = pd.get_dummies(north_york_venues[['Venue Category']], prefix="", prefix_sep="")

north_york_onehot['Neighborhood'] = north_york_venues['Neighborhood'] 

fixed_columns = [north_york_onehot.columns[-1]] + list(north_york_onehot.columns[:-1])
north_york_onehot = north_york_onehot[fixed_columns]

north_york_onehot.head()
# Out:
#   Neighborhood  ATM  ...  Women's Store  Yoga Studio
# 0    Parkwoods    0  ...              0            0
# 1    Parkwoods    0  ...              0            0
# 2    Parkwoods    0  ...              0            0
# 3    Parkwoods    0  ...              0            0
# 4    Parkwoods    0  ...              0            0
#
# [5 rows x 136 columns]

# %%
north_york_onehot.shape
# Out:
# (428, 136)

# %% [markdown]
# # Mean of neighbourhood categories

# %%
north_york_grouped = north_york_onehot.groupby('Neighborhood').mean().reset_index()
north_york_grouped
# Out:
#                                          Neighborhood  ...  Yoga Studio
# 0   Bathurst Manor , Wilson Heights , Downsview North  ...         0.00
# 1                                     Bayview Village  ...         0.00
# 2                  Bedford Park , Lawrence Manor East  ...         0.00
# 3                                           Don Mills  ...         0.00
# 4                                           Downsview  ...         0.00
# 5                      Fairview , Henry Farm , Oriole  ...         0.01
# 6                                           Glencairn  ...         0.00
# 7                                   Hillcrest Village  ...         0.00
# 8                                       Humber Summit  ...         0.00
# 9                                   Humberlea , Emery  ...         0.00
# 10                  Lawrence Manor , Lawrence Heights  ...         0.00
# 11         North Park , Maple Leaf Park , Upwood Park  ...         0.00
# 12                   Northwood Park , York University  ...         0.00
# 13                                          Parkwoods  ...         0.00
# 14                                   Victoria Village  ...         0.00
# 15                                         Willowdale  ...         0.00
# 16                           Willowdale , Newtonbrook  ...         0.00
# 17                          York Mills , Silver Hills  ...         0.00
# 18                                    York Mills West  ...         0.00
#
# [19 rows x 136 columns]

# %% [markdown]
# # Getting top 5 venues of each neighbourhood and their frequencies

# %%
num_top_venues = 5

for hood in north_york_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = north_york_grouped[north_york_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Bathurst Manor , Wilson Heights , Downsview North----
#             venue  freq
# 0            Bank  0.06
# 1  Ice Cream Shop  0.06
# 2     Coffee Shop  0.06
# 3        Pharmacy  0.06
# 4             Spa  0.06
#
#
# ----Bayview Village----
#                  venue  freq
# 0                 Café  0.17
# 1                  Gym  0.17
# 2   Chinese Restaurant  0.17
# 3                  Spa  0.17
# 4  Japanese Restaurant  0.17
#
#
# ----Bedford Park , Lawrence Manor East----
#                 venue  freq
# 0                 Spa  0.10
# 1  Italian Restaurant  0.06
# 2         Pizza Place  0.06
# 3    Sushi Restaurant  0.04
# 4    Business Service  0.04
#
#
# ----Don Mills----
#                  venue  freq
# 0                  Gym  0.10
# 1           Restaurant  0.07
# 2  Sporting Goods Shop  0.05
# 3       Clothing Store  0.05
# 4                 Café  0.05
#
#
# ----Downsview----
#                venue  freq
# 0       Home Service  0.08
# 1  Mobile Phone Shop  0.08
# 2   Business Service  0.08
# 3      Shopping Mall  0.08
# 4      Grocery Store  0.08
#
#
# ----Fairview , Henry Farm , Oriole----
#             venue  freq
# 0  Clothing Store  0.14
# 1   Women's Store  0.07
# 2      Shoe Store  0.06
# 3     Coffee Shop  0.05
# 4  Cosmetics Shop  0.05
#
#
# ----Glencairn----
#               venue  freq
# 0       Pizza Place  0.17
# 1               Spa  0.17
# 2            Bakery  0.08
# 3              Park  0.08
# 4  Business Service  0.08
#
#
# ----Hillcrest Village----
#                       venue  freq
# 0               Golf Course  0.17
# 1        Athletics & Sports  0.17
# 2                   Dog Run  0.17
# 3  Mediterranean Restaurant  0.17
# 4                      Pool  0.17
#
#
# ----Humber Summit----
#            venue  freq
# 0   Home Service  0.33
# 1       Pharmacy  0.33
# 2    Pizza Place  0.33
# 3            ATM  0.00
# 4  Metro Station  0.00
#
#
# ----Humberlea , Emery----
#                            venue  freq
# 0     Construction & Landscaping  0.25
# 1                 Baseball Field  0.25
# 2                    Fabric Shop  0.25
# 3  Paper / Office Supplies Store  0.25
# 4                   Noodle House  0.00
#
#
# ----Lawrence Manor , Lawrence Heights----
#                         venue  freq
# 0              Clothing Store  0.33
# 1      Furniture / Home Store  0.13
# 2           Accessories Store  0.08
# 3                Home Service  0.05
# 4  Construction & Landscaping  0.03
#
#
# ----North Park , Maple Leaf Park , Upwood Park----
#                         venue  freq
# 0                        Park  0.25
# 1                      Bakery  0.25
# 2              Massage Studio  0.25
# 3  Construction & Landscaping  0.25
# 4           Indian Restaurant  0.00
#
#
# ----Northwood Park , York University----
#                     venue  freq
# 0                     Spa  0.12
# 1  Furniture / Home Store  0.12
# 2            Optical Shop  0.06
# 3                Pharmacy  0.06
# 4      Falafel Restaurant  0.06
#
#
# ----Parkwoods----
#                         venue  freq
# 0  Construction & Landscaping   0.3
# 1                   BBQ Joint   0.1
# 2                       Hotel   0.1
# 3                    Bus Stop   0.1
# 4             Fireworks Store   0.1
#
#
# ----Victoria Village----
#                    venue  freq
# 0            Coffee Shop  0.14
# 1           Intersection  0.14
# 2           Hockey Arena  0.14
# 3            Pizza Place  0.14
# 4  Portuguese Restaurant  0.14
#
#
# ----Willowdale----
#                  venue  freq
# 0          Coffee Shop  0.07
# 1          Pizza Place  0.05
# 2     Ramen Restaurant  0.05
# 3  Japanese Restaurant  0.05
# 4            Pet Store  0.03
#
#
# ----Willowdale , Newtonbrook----
#                  venue  freq
# 0                 Park  0.33
# 1         Home Service  0.33
# 2                  Gym  0.33
# 3        Metro Station  0.00
# 4  Martial Arts School  0.00
#
#
# ----York Mills , Silver Hills----
#                  venue  freq
# 0                 Park  0.33
# 1  Martial Arts School  0.33
# 2            Cafeteria  0.33
# 3        Metro Station  0.00
# 4       Massage Studio  0.00
#
#
# ----York Mills West----
#                         venue  freq
# 0  Construction & Landscaping   0.2
# 1                        Park   0.2
# 2           Convenience Store   0.2
# 3                 Flower Shop   0.2
# 4           Electronics Store   0.2

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# # Neighbourhoods with their most common 10 venues

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = north_york_grouped['Neighborhood']

for ind in np.arange(north_york_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(north_york_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                         Neighborhood  ... 10th Most Common Venue
# 0  Bathurst Manor , Wilson Heights , Downsview North  ...     Chinese Restaurant
# 1                                    Bayview Village  ...     Dim Sum Restaurant
# 2                 Bedford Park , Lawrence Manor East  ...              Juice Bar
# 3                                          Don Mills  ...     Chinese Restaurant
# 4                                          Downsview  ...           Liquor Store
#
# [5 rows x 11 columns]

# %% [markdown]
# # K-means clustering with 3 clusters

# %%
kclusters = 3

north_york_grouped_clustering = north_york_grouped.drop('Neighborhood', 1)

kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(north_york_grouped_clustering)

kmeans.labels_[0:10]
# Out:
# array([2, 2, 2, 2, 2, 2, 2, 2, 2, 1], dtype=int32)

# %% [markdown]
# # Merge tables

# %%
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

north_york_merged = df3

north_york_merged = north_york_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighbourhood')

north_york_merged.head()
# Out:
#    PostalCode     Borough  ... 9th Most Common Venue  10th Most Common Venue
# 0         M3A  North York  ...           Yoga Studio      Dim Sum Restaurant
# 1         M4A  North York  ...        Cosmetics Shop            Cupcake Shop
# 3         M6A  North York  ...          Carpet Store          Lighting Store
# 7         M3B  North York  ...     Mobile Phone Shop      Chinese Restaurant
# 10        M6B  North York  ...      Business Service        Asian Restaurant
#
# [5 rows x 16 columns]

# %% [markdown]
# # map of clusters

# %%
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

markers_colors = []
for lat, lon, poi, cluster in zip(north_york_merged['Latitude'], north_york_merged['Longitude'],north_york_merged['Neighbourhood'], north_york_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_bbeeb25bf36c47cea33eca8f32b07933%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_bbeeb25bf36c47cea33eca8f32b07933%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_bbeeb25bf36c47cea33eca8f32b07933%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_bbeeb25bf36c47cea33eca8f32b07933%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B43.7543263%2C%20-79.44911696639593%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_613b5769c2ac4ffb9f4c23d1dc2afda9%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20 ...

# %% [markdown]
# # Examining data in each cluster

# %%
north_york_merged.loc[north_york_merged['Cluster Labels'] == 0, north_york_merged.columns[[1] + list(range(5, north_york_merged.shape[1]))]]
# Out:
#        Borough  Cluster Labels  ... 9th Most Common Venue 10th Most Common Venue
# 45  North York               0  ...          Dessert Shop           Cupcake Shop
#
# [1 rows x 12 columns]

# %%
north_york_merged.loc[north_york_merged['Cluster Labels'] == 1, north_york_merged.columns[[1] + list(range(5, north_york_merged.shape[1]))]]
# Out:
#        Borough  Cluster Labels  ... 9th Most Common Venue 10th Most Common Venue
# 0   North York               1  ...           Yoga Studio     Dim Sum Restaurant
# 49  North York               1  ...                 Diner     Dim Sum Restaurant
# 57  North York               1  ...                 Diner     Dim Sum Restaurant
# 66  North York               1  ...                 Diner     Dim Sum Restaurant
#
# [4 rows x 12 columns]

# %%
north_york_merged.loc[north_york_merged['Cluster Labels'] == 2, north_york_merged.columns[[1] + list(range(5, north_york_merged.shape[1]))]]
# Out:
#        Borough  ...  10th Most Common Venue
# 1   North York  ...            Cupcake Shop
# 3   North York  ...          Lighting Store
# 7   North York  ...      Chinese Restaurant
# 10  North York  ...        Asian Restaurant
# 13  North York  ...      Chinese Restaurant
# 27  North York  ...            Dessert Shop
# 28  North York  ...      Chinese Restaurant
# 33  North York  ...              Kids Store
# 34  North York  ...      Falafel Restaurant
# 39  North York  ...      Dim Sum Restaurant
# 40  North York  ...            Liquor Store
# 46  North York  ...            Liquor Store
# 50  North York  ...            Dessert Shop
# 52  North York  ...            Cupcake Shop
# 53  North York  ...            Liquor Store
# 55  North York  ...               Juice Bar
# 59  North York  ...           Grocery Store
# 60  North York  ...            Liquor Store
# 72  North York  ...           Grocery Store
#
# [19 rows x 12 columns]
